# %% [markdown]
# # Week6 Lab
#
# ## Download & Extract Data
#
# Programmatically download the zip file & extract

# %%
# import chardet

# with open('PoliceShootingsUS.csv', 'rb') as f:
#     content = f.read()
#     result = chardet.detect(content)
# result

# %%
from urllib import request

def download_file(file_name, url):
    res = request.urlopen(url)
    with open(file_name,'wb') as file:
        file.write(res.read())

# %%
from zipfile import ZipFile
file_url = 'https://github.com/msaricaumbc/DS_data/blob/master/lab_data.zip?raw=true'
file_name = 'lab_data.zip'
download_file(file_name, file_url)

# %%
def unzip(file_name, path='./'):
    # opening the zip file in READ mode 
    with ZipFile(file_name, 'r') as zip: 
        # printing all the contents of the zip file 
        zip.printdir() 

        # extracting all the files 
        print('Extracting all the files now...') 
        zip.extractall(path = path) 
        print('Done!')

# %%
unzip(file_name)
# Out:
# File Name                                             Modified             Size
# PoliceShootingsUS.csv                          2021-09-21 20:53:54       227653
# __MACOSX/._PoliceShootingsUS.csv               2021-09-21 20:53:54          276
# volunteers.txt                                 2021-10-06 00:32:28         7015
# __MACOSX/._volunteers.txt                      2021-10-06 00:32:28          176
# Extracting all the files now...
# Done!

# %% [markdown]
# ## Reading data from a csv file

# %% [markdown]
# For the file `PoliceShootingsUS.csv`, please answer the following questions:
#
# * How many offenders are older than 55?

# %%
## Your code is here


import chardet
with open('PoliceShootingsUS.csv', 'rb') as f:
    content = f.read()
    result = chardet.detect(content)
    print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
chardet.detect(open('PoliceShootingsUS.csv', 'rb').read())
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
import pandas as pd
police = pd.read_csv('PoliceShootingsUS.csv', encoding='Windows-1252')
police
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
len(police[(police.age > 55)])
# Out:
# 235

# %% [markdown]
# * What's the age distribution?

# %%
## Your code is here
import seaborn as sns
from matplotlib import pyplot as plt
sns.distplot(police['age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## Dirty data
#
# Read `volunteers.txt` file and perform the following action:
#
# * Create a dataframe with columns: Name, Lastname, State

# %%
## Your code is here
import re
with open('volunteers.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        res1 = re.findall(r'\[(.*)\]', line)
        res2 = re.findall(r'\((.*)\)', line)
        df = pd.DataFrame(list(zip(res1, res2)), columns = ['Fullname','value'])
        df[['Name', 'Lastname']] = df['Fullname'].str.split(',', expand=True)
        print(df[['Name', 'Lastname','value']])
# Out:
#       Name    Lastname     value
# 0  Harding   Christine  Virginia
#     Name   Lastname     value
# 0  Davis   Kimberly  New York
#      Name Lastname      value
# 0  Ingram   Rachel  Louisiana
#      Name  Lastname   value
# 0  Walker   Richard  Oregon
#      Name    Lastname     value
# 0  Barnes   Francisco  Virginia
#     Name Lastname   value
# 0  Perez   Rachel  Alaska
#    Name Lastname value
# 0  Choi    Linda  Iowa
#     Name Lastname    value
# 0  Gomez   Janice  Vermont
#     Name Lastname        value
# 0  Lloyd    Jesus  Connecticut
#     Name Lastname     value
# 0  Moore   Alicia  Michigan
#      Name Lastname    value
# 0  Murray   Pamela  Arizona
#     Name   Lastname       value
# 0  Moore   Brittney  Washington
#     Name    Lastname    value
# 0  Jones   Alexander  Arizona
#       Name Lastname    value
# 0  Morales    David  Florida
#     Name    Lastname         value
# 0  Hogan   Elizabeth  Rhode Island
#     Name   Lastname         value
# 0  Floyd   Courtney  Pennsylvania
#     Name Lastname          value
# 0  Scott     Mark  West Virginia
#       Name Lastname           value
# 0  Johnson   Philip  North Carolina
#      Name  Lastname          value
# 0  Taylor   Michael  New Hampshire
#       Name  Lastname         value
# 0  Freeman   Barbara  Pennsylvania
#        Name Lastname     value
# 0  Humphrey    Shawn  Oklahoma
#       Name Lastname           value
# 0  Schultz   Ernest  South Carolina
#      Name    Lastname        value
# 0  Harper   Alexander  Mississippi
#    Name Lastname     value
# 0  Shaw   Kendra  Nebraska
#     Name   Lastname      value
# 0  Glenn   Samantha  Louisiana
#       Name Lastname    value
# 0  Jackson     Kara  Wyoming
#      Name Lastname           value
# 0  Rivera   Vickie  North Carolina
#        Name  Lastname value
# 0  Robinson   Matthew  Iowa
#      Name Lastname   value
# 0  Taylor   Nicole  Kansas
#      Name Lastname         value
# 0  Harper     Eric  South Dakota
#     Name Lastname     value
# 0  Smith    Karen  Oklahoma
#      Name Lastname     value
# 0  Chavez   Donald  Nebraska
#        Name Lastname value
# 0  Thompson    Sarah  Ohio
#      Name   Lastname    value
# 0  Gibson   Veronica  Vermont
#      Name Lastname    value
# 0  Taylor   Steven  Montana
#        Name    Lastname           value
# 0  Mitchell   Alexandra  North Carolina
#       Name Lastname  value
# 0  Simmons   Nicole  Texas
#       Name Lastname         value
# 0  Ramirez    Riley  South Dakota
#     Name  Lastname     value
# 0  Lopez   Kenneth  Colorado
#    Name  Lastname     value
# 0  Rose   Jeffery  Kentucky
#     Name  Lastname      value
# 0  Brown   Nichole  Wisconsin
#         Name Lastname           value
# 0  Zimmerman     Mary  South Carolina
#        Name Lastname          value
# 0  Martinez   Andrew  Massachusetts
#    Name  Lastname      value
# 0  Mack   Richard  Tennessee
#      Name Lastname      value
# 0  Harris    Emily  Tennessee
#      Name  Lastname      value
# 0  Foster   Abigail  Tennessee
#     Name  Lastname   value
# 0  Hines   Michael  Alaska
#      Name   Lastname    value
# 0  Fields   Jennifer  Alabama
#      Name  Lastname     value
# 0  Austin   Roberto  Oklahoma
#    Name   Lastname     value
# 0  Choi   Kimberly  Maryland
#      Name Lastname          value
# 0  Jacobs    Susan  West Virginia
#       Name Lastname   value
# 0  Morales     Rita  Nevada
#       Name  Lastname         value
# 0  Morales   Matthew  Pennsylvania
#     Name Lastname    value
# 0  Payne   Trevor  Wyoming
#      Name  Lastname     value
# 0  Harmon   Melissa  Michigan
#      Name Lastname         value
# 0  Hooper     Paul  South Dakota
#     Name Lastname     value
# 0  Henry   Robert  Colorado
#    Name Lastname         value
# 0  Bell   Connor  Pennsylvania
#       Name  Lastname     value
# 0  Mercado   Charles  Arkansas
#      Name Lastname      value
# 0  Nelson   Ashley  Tennessee
#     Name Lastname     value
# 0  Lewis     Paul  New York
#      Name Lastname     value
# 0  Tanner   Ashley  Nebraska
#      Name  Lastname         value
# 0  Zavala   Jeffery  North Dakota
#      Name Lastname       value
# 0  Taylor    Kevin  Washington
#    Name   Lastname     value
# 0  Diaz   Michelle  Oklahoma
#        Name Lastname       value
# 0  Peterson   Shelly  New Mexico
#       Name Lastname value
# 0  Johnson    Robin  Iowa
#      Name Lastname    value
# 0  Daniel    Helen  Montana
#        Name  Lastname     value
# 0  Bartlett   Vanessa  New York
#      Name Lastname    value
# 0  Orozco    Emily  Vermont
#      Name Lastname         value
# 0  Bailey   Joseph  Rhode Island
#      Name Lastname   value
# 0  Hardin   Monica  Alaska
#       Name Lastname      value
# 0  Hartman    Jorge  Minnesota
#       Name   Lastname       value
# 0  Camacho   Jennifer  New Jersey
#     Name Lastname    value
# 0  Hardy    Amber  Vermont
#    Name Lastname         value
# 0  Ward    Tyler  Pennsylvania
#       Name Lastname    value
# 0  Jenkins    Ruben  Vermont
#      Name Lastname         value
# 0  Greene    Larry  South Dakota
#     Name Lastname      value
# 0  Wyatt    James  Wisconsin
#       Name Lastname   value
# 0  Leblanc   Travis  Oregon
#      Name Lastname    value
# 0  Rogers   Teresa  Wyoming
#      Name Lastname     value
# 0  Conley    Scott  Michigan
#      Name   Lastname   value
# 0  Murray   Patricia  Hawaii
#        Name Lastname          value
# 0  Matthews    Amber  Massachusetts
#     Name  Lastname   value
# 0  Munoz   Jessica  Kansas
#    Name Lastname       value
# 0  Ball   Andrea  Washington
#      Name Lastname     value
# 0  Wagner   Sydney  New York
#      Name    Lastname      value
# 0  Hebert   Stephanie  Minnesota
#          Name Lastname         value
# 0  Harrington   Joseph  South Dakota
#       Name Lastname         value
# 0  Jackson    David  North Dakota
#     Name  Lastname     value
# 0  Jones   Natalie  Michigan
#        Name Lastname value
# 0  Thornton     Seth  Iowa
#      Name Lastname      value
# 0  Nelson   Steven  Wisconsin
#     Name Lastname   value
# 0  Green   Robert  Kansas
#     Name  Lastname   value
# 0  Blair   Crystal  Kansas
#     Name Lastname         value
# 0  Smith    Kevin  North Dakota
#     Name Lastname   value
# 0  Moore     Mark  Alaska
#      Name   Lastname    value
# 0  Landry   Jennifer  Wyoming
#        Name Lastname     value
# 0  Phillips     Lori  Arkansas
#     Name  Lastname        value
# 0  Davis   Tiffany  Mississippi
