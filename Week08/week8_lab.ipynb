# %% [markdown]
# # Week8 - Lab
# ## Working with Strings
#
# [Kaggle ML & Data Science Survey - 2018](https://www.kaggle.com/kaggle/kaggle-survey-2018?select=freeFormResponses.csv)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_Data/master/freeFormResponses.csv', low_memory=False)

# %%
for i, question in enumerate(df.loc[0].values):
    print(i, question)
# Out:
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Other - Text
# 1 What is the primary tool that you use at work or school to analyze data? (include text response) - Other - Text
# 2 What is the primary tool that you use at work or school to analyze data? (include text response) - Basic statistical software (Microsoft Excel, Google Sheets, etc.) - Text
# 3 What is the primary tool that you use at work or school to analyze data? (include text response) - Advanced statistical software (SPSS, SAS, etc.) - Text
# 4 What is the primary tool that you use at work or school to analyze data? (include text response) - Business intelligence software (Salesforce, Tableau, Spotfire, etc.) - Text
# 5 What is the primary tool that you use at work or school to analyze data? (include text response) - Local or hosted development environments (RStudio, JupyterLab, etc.) - Text
# ...

# %%
df.loc[:, 'Q12_Part_4_TEXT'].value_counts().sort_values(ascending =False)[150:200]
# Out:
# Python 3.6                      3
# Spyder, Jupyter Notebook        3
# Jupyter Lab                     3
# py                              3
# Jupyter Notebook, PyCharm       3
# Python R                        3
# R & Python                      3
# Visual Studio                   3
# Knime                           3
# Python & R                      3
# Studio                          3
# JupyterNotebooks                3
# Python,R                        3
# R, Spyder                       3
# SQL Server                      3
# Anaconda Spyder                 3
# RStudio, JupiterLab             3
# R Studio, Jupyter               3
# Jupiter notebooks               3
# Rstudio, Jupyterlab             3
# JupyterLab, Jupyter Notebook    3
# Python, Jupyterlab              3
# jupyter notebook                3
# Jupyter Notebook, RStudio       3
# jupyter-notebook                3
# RStudio,Anaconda                3
# JUPYTER                         3
# ...

# %% [markdown]
# __Your Task__
#
# - In  `Q12_Part_4_TEXT` they ask the tools the participants are using day to day. However as you might observe the answers are not standardized.
#
# - Find all the answers with 'jupyter' mentioned in it.
#
# - Find all the participant who are Python users.
#
# - Find all R users.

# %%
import re

# %%
df.fillna('', inplace = True)

# %%
df[df['Q12_Part_4_TEXT'].str.lower().str.contains('jupyter|jupiter|juypter|jupytet|juptyterLab|jut|jyp|jputer|juupyter|julyterlab|julyter lab|jupytrer|jupter|juputerlab|juoyterlab|jup|júpiter')]['Q12_Part_4_TEXT']
# Out:
# 0        What is the primary tool that you use at work ...
# 1                  Jupyter Notebooks, Pycharm, Intelijidea
# 7                                               JupyterLab
# 9                                               Jupyterlab
# 12                            JupyterLab, Jupyter Notebook
#                                ...
# 23825                                          Jupyterlab
# 23836                                              jupyter
# 23847                                              Jupyter
# 23848                                      jupter notebook
# 23857                                  JupyterLab, RStudio
# Name: Q12_Part_4_TEXT, Length: 4718, dtype: object

# %%
for _, i in df[-df['Q12_Part_4_TEXT'].str.lower().str.contains('jupyter|jupiter|juypter|jupytet|juptyterLab|jut|jyp|jputer|juupyter|julyterlab|julyter lab|jupytrer|jupter|juputerlab|juoyterlab|jup|júpiter|pyth|pygame|pytjhon|python|pyton|phyton|pyh|pyspark|pyscripter|pyhon|pycharm|py charm|pytorch|pytprch|pytouch|phthon|puchar|pynotebook|pydata|ipython|pystudio|pydev|pytohn|^r$|^ r $|\br\b|r\w{2,3}dio|r studio|rstuido|r language|^r,|r-studio|rstudii|r software|rstudeo|rstudia|r server|r programming')]['Q12_Part_4_TEXT'].iteritems():
    print(i)
# Out:
# anaconda
#
#
#
#
#
#
#
#
#
#
#
#
# We use these to complete assignments
#
#
#
#
#
#
#
#
#
#
# Datalab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# local pc anaconda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Spyder, matlab
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c# accord
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Spyder
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Keras
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Spyder
#
#
#
#
#
#
# Also SAS.
# Matlab
#
#
#
#
#
# IDE
#
#
#
#
#
#
#
#
# Tensorflow
#
#
#
#
#
#
# H2O.ai
#
#
#
#
#
#
#
#
# Spyder, Orange3, Microsoft Excel and Access
#
#
#
#
#
#
#
#
#
#
#
# Na
#
#
#
#
# Pandas
#
#
#
# Anaconda
#
#
#
#
#
#
#
#
# combination of scripts and ml libraries
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  None
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ms-Excel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Local Linux
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
df[df['Q12_Part_4_TEXT'].str.lower().str.contains('pyth|pygame|pytjhon|python|pyton|phyton|pyh|pyspark|pyscripter|pyhon|pycharm|py charm|pytorch|pytprch|pytouch|phthon|puchar|pynotebook|pydata|ipython|pystudio|pydev|pytohn')]['Q12_Part_4_TEXT']
# Out:
# 1        Jupyter Notebooks, Pycharm, Intelijidea
# 6                            Python in Notebooks
# 19                               Rstudio, python
# 28                                        Python
# 41                        JupyterLab and PyCharm
#                           ...
# 23830                                     python
# 23831     Clojure, Python, R, Bash, Spark, Scala
# 23837                          Python data stack
# 23850                python, pytorch, tensorflow
# 23852                                     Python
# Name: Q12_Part_4_TEXT, Length: 2801, dtype: object

# %%
df[df['Q12_Part_4_TEXT'].str.lower().str.contains('^r$|^ r $|\br\b|r\w{2,3}dio|r studio|rstuido|rstudia|r language|^r,|r-studio|rstudii|r software|rstudeo|r server|r programming')]['Q12_Part_4_TEXT']
# Out:
# 0        What is the primary tool that you use at work ...
# 10                                                 Rstudio
# 15                                                     R,
# 19                                         Rstudio, python
# 24                                       Rstudio; julpyter
#                                ...
# 23814                                              rstudio
# 23838                                              Rstudio
# 23846                                             Rstudio
# 23849                                             R studio
# 23857                                  JupyterLab, RStudio
# Name: Q12_Part_4_TEXT, Length: 2824, dtype: object
