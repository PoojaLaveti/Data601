# %% [markdown]
# # Week 11 Homework - Getting data
#
#
# 1. Load the dataframe saved from this week's lab.
# 1. Scrape data from this page https://en.wikipedia.org/wiki/List_of_countries_by_past_and_projected_GDP_(nominal)
# 1. Append to the dataframe: projected GDP (nominal) from IMF estimates from 2022 to 2027. (If data is not available for the country use None)
# 1. Add a new column and calculate average increase in terms of percentage.
# 1. Sort by this column in descending order.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://github.com/PoojaLaveti/Data601/blob/main/Week11/Countries_of_the_World.csv')
response.ok
# Out:
# False

# %%
df = pd.read_csv("Countries_of_the_World.csv")
df
# Out:
#      Unnamed: 0          Country_Name   Country_Capital  Country_Population  \
# 0             0               Andorra  Andorra la Vella               84000
# 1             1  United Arab Emirates         Abu Dhabi             4975593
# 2             2           Afghanistan             Kabul            29121286
# 3             3   Antigua and Barbuda        St. John's               86754
# 4             4              Anguilla        The Valley               13254
# ..          ...                   ...               ...                 ...
# 245         245                 Yemen             Sanaa            23495361
# 246         246               Mayotte         Mamoudzou              159042
# 247         247          South Africa          Pretoria            49000000
# 248         248                Zambia            Lusaka            13460305
# 249         249              Zimbabwe            Harare            11651858
#
#      Country_Area
# 0           468.0
# ...

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_countries_by_past_and_projected_GDP_(nominal)')
response.ok
# Out:
# True

# %%
response.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by past and projected GDP (nominal) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b9655fdf-4dfe-4d4c-87b3-abf25df44a6d","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_past_and_projected_GDP_(nominal)","wgTitle":"List of countries by past and projected GDP (nominal)","wgCurRevisionId":1085636478,"wgRevisionId":1085636478,"wgArticleId":1424142,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short descr
# ...

# %%
html_doc = response.text

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by past and projected GDP (nominal) - Wikipedia
#   </title>
#   <script>
# ...

# %%
every_table = soup.findAll('table')
print(type(every_table))
print(len(every_table))
# Out:
# <class 'bs4.element.ResultSet'>
# 14

# %%
every_table[0]
# Out:
# <table border="1" class="wikitable sortable static-row-numbers plainrowheaders srn-white-background" style="text-align:right;">
# <tbody><tr class="static-row-header" style="text-align:center;vertical-align:bottom;">
# <th>Country (or area)</th>
# <th>1970</th>
# <th>1971</th>
# <th>1972</th>
# <th>1973</th>
# <th>1974</th>
# <th>1975</th>
# <th>1976</th>
# <th>1977</th>
# <th>1978</th>
# <th>1979
# </th></tr>
# <tr>
# ...

# %%
t = soup.find_all('td')
block=t[0]
block
# Out:
# <td style="text-align:left"><span class="flagicon" style="display:inline-block;width:25px;text-align:left;"><img alt="" class="thumbborder" data-file-height="500" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/23px-Flag_of_the_Taliban.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/35px-Flag_of_the_Taliban.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/46px-Flag_of_the_Taliban.svg.png 2x" width="23"/></span> <a href="/wiki/Economy_of_Afghanistan" title="Economy of Afghanistan">Afghanistan *</a></td>

# %%
table_rows = every_table[0].findAll('a')
print(table_rows[0])
# Out:
# <a href="/wiki/Economy_of_Afghanistan" title="Economy of Afghanistan">Afghanistan *</a>

# %%
import re
m = re.findall('title.*</a>', response.text)
m
# Out:
# ['title="Gross domestic product">gross domestic product</a> (nominal)</b> as ranked by the IMF. Figures are based on official <a href="/wiki/Exchange_rate" title="Exchange rate">exchange rates</a>, not on the <a href="/wiki/Purchasing_power_parity" title="Purchasing power parity">purchasing power parity</a> (PPP) methodology. Values are given in millions of <a href="/wiki/United_States_dollar" title="United States dollar">United States dollars</a> (USD) and have not been adjusted for inflation. These figures have been taken from the <a href="/wiki/International_Monetary_Fund" title="International Monetary Fund">International Monetary Fund</a>\'s World Economic Outlook (WEO) Database (April 2022 edition) and/or other sources.<sup id="cite_ref-IMF_Data_1-0" class="reference"><a href="#cite_note-IMF_Data-1">&#91;1&#93;</a>',
#  'title="List of regions by past GDP (PPP)">List of regions by past GDP (PPP)</a>',
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# None
# #mw-head
# #searchInput
# /wiki/Gross_domestic_product
# /wiki/Exchange_rate
# /wiki/Purchasing_power_parity
# /wiki/United_States_dollar
# /wiki/International_Monetary_Fund
# #cite_note-IMF_Data-1
# /wiki/List_of_regions_by_past_GDP_(PPP)
# #UN_estimates_between_1970_and_1979
# #IMF_estimates_between_1980_and_1989
# #IMF_estimates_between_1990_and_1999
# #IMF_estimates_between_2000_and_2009
# #IMF_estimates_between_2010_and_2019
# #IMF_projections_for_2020_through_2027
# #CIA_estimates_in_1990
# #GDP_milestones_by_countries_(in_trillions_USD)
# #Long_term_GDP_estimates
# #See_also
# #References
# #External_links
# /wiki/UN
# #cite_note-2
# #cite_note-3
# /wiki/Economy_of_Afghanistan
# /wiki/Economy_of_Albania
# /wiki/Economy_of_Algeria
# /wiki/Economy_of_Andorra
# /wiki/Economy_of_Angola
# /wiki/Economy_of_Anguilla
# /wiki/Economy_of_Antigua_and_Barbuda
# /wiki/GDP_of_Argentina
# /wiki/Economy_of_Armenia
# /wiki/Economy_of_Aruba
# /wiki/Economy_of_Australia
# ...
